# %%
import pandas as pd

data = pd.read_csv('Datasets/sentiment140.csv', header=None, names=['polarity', 'id', 'date', 'query', 'user', 'text'])
data = data[['polarity', 'text']]
data
# Out:
#          polarity                                               text
# 0               0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1               0  is upset that he can't update his Facebook by ...
# 2               0  @Kenichan I dived many times for the ball. Man...
# 3               0    my whole body feels itchy and like its on fire
# 4               0  @nationwideclass no, it's not behaving at all....
# ...           ...                                                ...
# 1599995         4  Just woke up. Having no school is the best fee...
# 1599996         4  TheWDB.com - Very cool to hear old Walt interv...
# 1599997         4  Are you ready for your MoJo Makeover? Ask me f...
# 1599998         4  Happy 38th Birthday to my boo of alll time!!! ...
# 1599999         4  happy #charitytuesday @theNSPCC @SparksCharity...
#
# [1600000 rows x 2 columns]

# %%
import emoji

def contains_emoji(text):
    """Check if a text contains any emojis."""
    return any(char in emoji.EMOJI_DATA for char in text)

# %%
def extract_emojis(text):
    """Extract all emojis from a given text."""
    return ''.join([char for char in text if char in emoji.EMOJI_DATA])

# %%
# Check if each row contains an emoji
data['has_emoji'] = data['text'].apply(extract_emojis)

# Filter rows with emojis
rows_with_emojis = data[data['has_emoji'].str.len() > 0]

print(rows_with_emojis[['text', 'has_emoji']])
# Out:
#                                                       text has_emoji
# 242372   @AndrewDearling haha, well they are a mjor par...         ♥
# 244527   Le planetarium de montreal: le show est nul et...         ©
# 245409   okeei, whay all the men has to be like this?? ...         ♥
# 245432    @Kulnyte its ok.  wish you were here though//  ♥         ♥
# 246784                *♥* Twitter is so confuddlin me  *♥*        ♥♥
# ...                                                    ...       ...
# 1596602  @andymcnally so far so good   &lt;&lt;hugs&gt;...         ♥
# 1596991  http://www.twitpic.com/7jka4 ♥Italian Stuffed ...        ♥♥
# 1597694          LVATT ♥♥♥ out in stores today! GO BUY IT        ♥♥♥
# 1598666  Enjoyin' a lazy day off and making/finishing p...         ♥
# 1599461           I ♥ LVATT. although i don't have it yet          ♥
#
# [1338 rows x 2 columns]

# %%
instagram_data = pd.read_excel('Datasets/instagram.xlsx')
instagram_data = instagram_data[instagram_data['Full Language'] == 'English']
instagram_data
# Out:
#              PostID                                   Post Description  \
# 0       B7mbLCVhYIf  QUESTIONS AND ANSWERS ON CORONAVIRUS PT. 2\n\n...
# 3       B7m7M3SgvI1  Using humor to bring attention to a serious ma...
# 4       B7oK_DMhtxr  Stay safe\nCover your face\n#typ262 #40mm #40m...
# 5       B7njeFbBX5y  Did you know an outbreak of a new coronavirus ...
# 7       B7nV26QgOLP  It’s so sad and scary that the coronavirus has...
# ...             ...                                                ...
# 500142  DAMEDoQs_9T  🎉Joanna Loeber and Tomás Yan representing our ...
# 500144  DAOmX_Go2jG  Hang in there ❤️\n.\nI know that it's hard to ...
# 500146  DAOUlpwpfk5  NOTICE THIS REFERS TO RESEARCHERS FOR BOTH HUM...
# 500149  DARcSwAB8NH  ✨Care for COVID: Crafting Day Recap🤩🫶\n\nThank...
# 500152  DAQ7C3LuZ0w  What Doctors Want You to Know About XEC, the N...
#
#               Date Language Code Full Language Sentiment
# 0       01/21/2020            en       English  positive
# ...

# %%
instagram_data = instagram_data[['Post Description', 'Sentiment']]
instagram_data.iloc[111]['Post Description']
# Out:
# 'Sharing the daily routine of medical staff at an isolated living apartment. Temperature is checked twice a day, the whole apartment gets decontaminated in the morning and the afternoon, and staff provides three meals a day to the doorstep.\n\n中国加油(china jiayou)=China you can do it, keep fighting!\n#ChinaJiayou #wuhancoronavirus #coronavirus #chinavirus #coronaviruschina #chinacoronavirus #wuhancoronaoutbreak #chinavirusnews #corona #coronavirusawareness #wuhan #wuhanvirus #武汉加油 #中国加油'
